# %% [markdown]
# # TP Máquina de Turing Calculable
# ---

# %% [markdown]
# Calcular la imagen especular de una cadena definida sobre {a, b}, es decir, f(w)=reverso(w). Ejemplos: f(aabb)=bbaa y f(aba)=aba

# %% [markdown]
# Ejemplos:
#
# - `aabb → bbaa`
# - `aba → aba`
#
# ### Diagrama de estados
#
# <p align="center">
#   <img src="images/reverso_cadena.png"
#        alt="Máquina de Turing para invertir una cadena"
#        width="900">
# </p>
#
# ### Tabla de transiciones
#
# | Estado actual | Lee | Escribe | Movimiento | Estado siguiente |
# |:-------------:|:---:|:-------:|:----------:|:----------------:|
# | q0 | a | a | R | q0 |
# | q0 | b | b | R | q0 |
# | q0 | □ | # | L | q1 |
# | q1 | X | X | L | q1 |
# | q1 | a | X | R | q2 |
# | q1 | b | X | R | q4 |
# | q1 | □ | □ | R | q7 |
# | q2 | a | a | R | q2 |
# | q2 | b | b | R | q2 |
# | q2 | X | X | R | q2 |
# | q2 | # | # | R | q3 |
# | q3 | a | a | R | q3 |
# | q3 | b | b | R | q3 |
# | q3 | □ | a | L | q6 |
# | q4 | a | a | R | q4 |
# | q4 | b | b | R | q4 |
# | q4 | X | X | R | q4 |
# | q4 | # | # | R | q5 |
# | q5 | a | a | R | q5 |
# | q5 | b | b | R | q5 |
# | q5 | □ | b | L | q6 |
# | q6 | a | a | L | q6 |
# | q6 | b | b | L | q6 |
# | q6 | # | # | L | q1 |
# | q7 | X | □ | R | q7 |
# | q7 | # | □ | R | q8 |
#
# ### Descripción de los estados
#
# | Estado | Función |
# |:------:|---------|
# | q0 | Recorre la cadena original hasta encontrar el final y coloca `#`. |
# | q1 | Busca de derecha a izquierda el próximo símbolo que todavía no fue procesado. |
# | q2 | Recuerda que el símbolo encontrado fue `a` y avanza hacia `#`. |
# | q3 | Busca el final de la salida y escribe `a`. |
# | q4 | Recuerda que el símbolo encontrado fue `b` y avanza hacia `#`. |
# | q5 | Busca el final de la salida y escribe `b`. |
# | q6 | Regresa hacia la izquierda hasta encontrar el separador `#`. |
# | q7 | Elimina las marcas `X` utilizadas durante el procesamiento. |
# | q8 | Estado final. |

# %% [markdown]
# Duplicar una cadena de aes y bes en la cinta. Ejemplo: si la MT comienza con abbaa□ en su cinta, luego de procesar su programa debe terminar con abbaa□abbaa

# %% [markdown]
# Ejemplos:
#
# - `abbaa → abbaa□abbaa`
# - `aba → aba□aba`
# - `aab → aab□aab`
#
# ### Diagrama de estados
#
# <p align="center">
#   <img src="images/duplicar_cadena.png"
#        alt="Máquina de Turing para duplicar una cadena"
#        width="900">
# </p>
#
# ### Tabla de transiciones
#
# | Estado actual | Lee | Escribe | Movimiento | Estado siguiente |
# |:-------------:|:---:|:-------:|:----------:|:----------------:|
# | q0 | a | a | R | q0 |
# | q0 | b | b | R | q0 |
# | q0 | □ | # | L | q1 |
# | q1 | a | a | L | q1 |
# | q1 | b | b | L | q1 |
# | q1 | A | A | L | q1 |
# | q1 | B | B | L | q1 |
# | q1 | # | # | L | q1 |
# | q1 | □ | □ | R | q2 |
# | q2 | A | A | R | q2 |
# | q2 | B | B | R | q2 |
# | q2 | a | A | R | q3 |
# | q2 | b | B | R | q4 |
# | q2 | # | □ | L | q7 |
# | q3 | a | a | R | q3 |
# | q3 | b | b | R | q3 |
# | q3 | A | A | R | q3 |
# | q3 | B | B | R | q3 |
# | q3 | # | # | R | q5 |
# | q4 | a | a | R | q4 |
# | q4 | b | b | R | q4 |
# | q4 | A | A | R | q4 |
# | q4 | B | B | R | q4 |
# | q4 | # | # | R | q6 |
# | q5 | a | a | R | q5 |
# | q5 | b | b | R | q5 |
# | q5 | □ | a | L | q1 |
# | q6 | a | a | R | q6 |
# | q6 | b | b | R | q6 |
# | q6 | □ | b | L | q1 |
# | q7 | A | a | L | q7 |
# | q7 | B | b | L | q7 |
# | q7 | □ | □ | R | q8 |
#
# ### Descripción de los estados
#
# | Estado | Función |
# |:------:|---------|
# | q0 | Recorre la cadena original hasta encontrar el final y coloca el separador temporal `#`. |
# | q1 | Regresa hacia la izquierda hasta encontrar el comienzo de la cadena original. |
# | q2 | Busca de izquierda a derecha el próximo símbolo que todavía no fue copiado. Ignora las marcas `A` y `B`. |
# | q3 | Recuerda que el símbolo encontrado fue `a` y avanza hacia el separador `#`. |
# | q4 | Recuerda que el símbolo encontrado fue `b` y avanza hacia el separador `#`. |
# | q5 | Recorre la copia construida hasta encontrar un blanco y escribe `a`. |
# | q6 | Recorre la copia construida hasta encontrar un blanco y escribe `b`. |
# | q7 | Restaura la cadena original reemplazando `A` por `a` y `B` por `b`. |
# | q8 | Estado final. |

# %% [markdown]
# Se dispone de una cinta en la que hay un número m de 1s seguido de un número n ≥ m de Aes. Se desea definir una MT que cambie las primeras m Aes por Bes. Se supone que la cabeza de la cinta inicialmente está en el 1 más a la izquierda

# %% [markdown]
# Ejemplos:
#
# - `111AAAAA → 111BBBAA`
# - `11AAAA → 11BBAA`
# - `1AAA → 1BAA`
#
# ### Diagrama de estados
#
# <p align="center">
#   <img src="images/cambiar_a_por_b.png"
#        alt="Máquina de Turing que cambia las primeras m Aes por Bes"
#        width="900">
# </p>
#
# ### Tabla de transiciones
#
# | Estado actual | Lee | Escribe | Movimiento | Estado siguiente |
# |:-------------:|:---:|:-------:|:----------:|:----------------:|
# | q0 | X | X | R | q0 |
# | q0 | 1 | X | R | q1 |
# | q0 | B | B | L | q3 |
# | q1 | 1 | 1 | R | q1 |
# | q1 | X | X | R | q1 |
# | q1 | B | B | R | q1 |
# | q1 | A | B | L | q2 |
# | q2 | 1 | 1 | L | q2 |
# | q2 | X | X | L | q2 |
# | q2 | B | B | L | q2 |
# | q2 | □ | □ | R | q0 |
# | q3 | X | 1 | L | q3 |
# | q3 | □ | □ | R | q4 |
#
# ### Descripción de los estados
#
# | Estado | Función |
# |:------:|---------|
# | q0 | Busca el próximo `1` que todavía no fue procesado. Los `1` ya utilizados están marcados como `X`. |
# | q1 | Después de marcar un `1`, avanza hacia la derecha buscando la primera `A` que todavía no fue cambiada. Ignora las `B` ya procesadas. |
# | q2 | Luego de cambiar una `A` por `B`, regresa hacia el comienzo de la cinta para buscar otro `1` sin procesar. |
# | q3 | Cuando ya no quedan `1` sin procesar, restaura las marcas reemplazando cada `X` por `1`. |
# | q4 | Estado final. |

# %% [markdown]
# Comprobar si dos palabras formadas con símbolos de Σ = {0, 1, 2} son iguales. Las dos palabras están separadas por el símbolo #

# %%
Ejemplos:

- `012#012 → acepta`
- `102#102 → acepta`
- `012#021 → rechaza`
- `01#012 → rechaza`

### Tabla de transiciones

| Estado actual | Lee | Escribe | Movimiento | Estado siguiente |
|:-------------:|:---:|:-------:|:----------:|:----------------:|
| q0 | X | X | R | q0 |
| q0 | Y | Y | R | q0 |
| q0 | Z | Z | R | q0 |
| q0 | 0 | X | R | q1 |
| q0 | 1 | Y | R | q2 |
| q0 | 2 | Z | R | q3 |
| q0 | # | # | R | q8 |
| q0 | □ | □ | R | q9 |
| q1 | 0 | 0 | R | q1 |
| q1 | 1 | 1 | R | q1 |
| q1 | 2 | 2 | R | q1 |
| q1 | X | X | R | q1 |
| q1 | Y | Y | R | q1 |
| q1 | Z | Z | R | q1 |
| q1 | # | # | R | q4 |
| q1 | □ | □ | R | q9 |
| q2 | 0 | 0 | R | q2 |
| q2 | 1 | 1 | R | q2 |
| q2 | 2 | 2 | R | q2 |
| q2 | X | X | R | q2 |
| q2 | Y | Y | R | q2 |
| q2 | Z | Z | R | q2 |
| q2 | # | # | R | q5 |
| q2 | □ | □ | R | q9 |
| q3 | 0 | 0 | R | q3 |
| q3 | 1 | 1 | R | q3 |
| q3 | 2 | 2 | R | q3 |
| q3 | X | X | R | q3 |
| q3 | Y | Y | R | q3 |
| q3 | Z | Z | R | q3 |
| q3 | # | # | R | q6 |
| q3 | □ | □ | R | q9 |
| q4 | X | X | R | q4 |
| q4 | Y | Y | R | q4 |
| q4 | Z | Z | R | q4 |
| q4 | 0 | X | L | q7 |
| q4 | 1 | 1 | R | q9 |
| q4 | 2 | 2 | R | q9 |
| q4 | □ | □ | R | q9 |
| q5 | X | X | R | q5 |
| q5 | Y | Y | R | q5 |
| q5 | Z | Z | R | q5 |
| q5 | 1 | Y | L | q7 |
| q5 | 0 | 0 | R | q9 |
| q5 | 2 | 2 | R | q9 |
| q5 | □ | □ | R | q9 |
| q6 | X | X | R | q6 |
| q6 | Y | Y | R | q6 |
| q6 | Z | Z | R | q6 |
| q6 | 2 | Z | L | q7 |
| q6 | 0 | 0 | R | q9 |
| q6 | 1 | 1 | R | q9 |
| q6 | □ | □ | R | q9 |
| q7 | 0 | 0 | L | q7 |
| q7 | 1 | 1 | L | q7 |
| q7 | 2 | 2 | L | q7 |
| q7 | X | X | L | q7 |
| q7 | Y | Y | L | q7 |
| q7 | Z | Z | L | q7 |
| q7 | # | # | L | q7 |
| q7 | □ | □ | R | q0 |
| q8 | X | X | R | q8 |
| q8 | Y | Y | R | q8 |
| q8 | Z | Z | R | q8 |
| q8 | 0 | 0 | R | q9 |
| q8 | 1 | 1 | R | q9 |
| q8 | 2 | 2 | R | q9 |
| q8 | # | # | R | q9 |
| q8 | □ | □ | R | q10 |

### Descripción de los estados

| Estado | Función |
|:------:|---------|
| q0 | Busca el próximo símbolo sin procesar de la primera palabra. Marca `0` como `X`, `1` como `Y` y `2` como `Z`. Si llega a `#`, significa que ya procesó toda la primera palabra. |
| q1 | Recuerda que se seleccionó un `0` y avanza hacia la derecha hasta encontrar el separador `#`. |
| q2 | Recuerda que se seleccionó un `1` y avanza hacia la derecha hasta encontrar el separador `#`. |
| q3 | Recuerda que se seleccionó un `2` y avanza hacia la derecha hasta encontrar el separador `#`. |
| q4 | Busca el próximo símbolo sin procesar de la segunda palabra y comprueba que sea `0`. Si coincide, lo marca como `X`; si no coincide, pasa al estado de rechazo. |
| q5 | Busca el próximo símbolo sin procesar de la segunda palabra y comprueba que sea `1`. Si coincide, lo marca como `Y`; si no coincide, pasa al estado de rechazo. |
| q6 | Busca el próximo símbolo sin procesar de la segunda palabra y comprueba que sea `2`. Si coincide, lo marca como `Z`; si no coincide, pasa al estado de rechazo. |
| q7 | Regresa hacia la izquierda hasta encontrar el blanco anterior al comienzo de la primera palabra y vuelve a `q0`. |
| q8 | Comprueba que no hayan quedado símbolos sin procesar en la segunda palabra. Si encuentra solamente `X`, `Y` y `Z` hasta llegar al blanco, ambas palabras tienen la misma longitud y contenido. |
| q9 | Estado de rechazo. Se alcanza cuando los símbolos comparados son diferentes o cuando las palabras tienen distinta longitud. |
| q10 | Estado final de aceptación. Las dos palabras son iguales. |

# %% [markdown]
# Sumatoria de (n + i) , con 1 ≤ i ≤ n, con n codificado en unario

# %% [markdown]
# Ejemplos:
#
# - `1 → 11`
# - `11 → 1111111`
# - `111 → 111111111111111`
#
# ### Tabla de transiciones
#
# | Estado actual | Lee | Escribe | Movimiento | Estado siguiente |
# |:-------------:|:---:|:-------:|:----------:|:----------------:|
# | q0 | 1 | 1 | R | q0 |
# | q0 | □ | # | L | q1 |
# | q1 | 1 | 1 | L | q1 |
# | q1 | □ | □ | R | q2 |
# | q2 | X | X | R | q2 |
# | q2 | 1 | X | L | q3 |
# | q2 | # | # | L | q12 |
# | q3 | 1 | 1 | L | q3 |
# | q3 | X | X | L | q3 |
# | q3 | □ | □ | R | q4 |
# | q4 | A | A | R | q4 |
# | q4 | B | B | R | q4 |
# | q4 | X | A | R | q5 |
# | q4 | 1 | B | R | q5 |
# | q4 | # | # | L | q7 |
# | q5 | A | A | R | q5 |
# | q5 | B | B | R | q5 |
# | q5 | X | X | R | q5 |
# | q5 | 1 | 1 | R | q5 |
# | q5 | # | # | R | q5 |
# | q5 | □ | 1 | L | q6 |
# | q6 | 1 | 1 | L | q6 |
# | q6 | # | # | L | q6 |
# | q6 | X | X | L | q6 |
# | q6 | A | A | L | q6 |
# | q6 | B | B | L | q6 |
# | q6 | □ | □ | R | q4 |
# | q7 | A | X | L | q7 |
# | q7 | B | 1 | L | q7 |
# | q7 | X | X | L | q7 |
# | q7 | 1 | 1 | L | q7 |
# | q7 | □ | □ | R | q8 |
# | q8 | A | A | R | q8 |
# | q8 | X | A | R | q9 |
# | q8 | 1 | 1 | L | q11 |
# | q8 | # | # | L | q11 |
# | q9 | A | A | R | q9 |
# | q9 | X | X | R | q9 |
# | q9 | 1 | 1 | R | q9 |
# | q9 | # | # | R | q9 |
# | q9 | □ | 1 | L | q10 |
# | q10 | 1 | 1 | L | q10 |
# | q10 | # | # | L | q10 |
# | q10 | X | X | L | q10 |
# | q10 | A | A | L | q10 |
# | q10 | □ | □ | R | q8 |
# | q11 | A | X | L | q11 |
# | q11 | X | X | L | q11 |
# | q11 | □ | □ | R | q2 |
# | q12 | X | □ | L | q12 |
# | q12 | □ | □ | R | q13 |
# | q13 | □ | □ | R | q13 |
# | q13 | # | □ | R | q14 |
#
# ### Descripción de los estados
#
# | Estado | Función |
# |:------:|---------|
# | q0 | Recorre el número `n` codificado en unario y coloca el separador temporal `#` al final de la entrada. |
# | q1 | Regresa hasta el comienzo de la cadena después de haber colocado `#`. |
# | q2 | Controla la iteración principal. Busca el próximo `1` de la entrada todavía no procesado y lo marca como `X`. Cada `X` representa un valor de `i` ya alcanzado. |
# | q3 | Regresa al comienzo de la entrada después de marcar un nuevo `X`. |
# | q4 | Recorre todos los símbolos que representan a `n`. Usa `A` y `B` como marcas temporales para copiar una vez cada símbolo de la entrada. De esta forma agrega `n` unos al resultado. |
# | q5 | Avanza hasta el final de la zona de resultado y agrega un `1`. |
# | q6 | Regresa al comienzo para continuar copiando los símbolos restantes de `n`. |
# | q7 | Restaura las marcas temporales de la copia de `n`: `A → X` y `B → 1`. |
# | q8 | Recorre los `X` que representan el valor actual de `i`. Por cada `X` agrega un `1` al resultado, realizando así la suma del término `i`. |
# | q9 | Avanza hasta el final del resultado para agregar un `1` correspondiente al valor de `i`. |
# | q10 | Regresa al comienzo para continuar copiando los `X` restantes del valor actual de `i`. |
# | q11 | Restaura las marcas `A → X` utilizadas durante la copia de `i` y vuelve a buscar el siguiente `1` de la entrada. |
# | q12 | Cuando todos los `1` originales fueron procesados, elimina los `X` de la entrada. |
# | q13 | Avanza sobre los blancos hasta encontrar el separador `#` y lo elimina. |
# | q14 | Estado final. En la cinta queda únicamente el resultado de la sumatoria codificado en unario. |

# %% [markdown]
# [(x*y) / 2], para x, y > 0 codificados en unario

# %% [markdown]
# x mod y, para x, y > 0, codificados en unario

# %% [markdown]
# La parte entera superior del promedio de n números mayores que cero codificados en unario. Usar como separador de números unarios en la cinta de entrada al símbolo 0. Ejemplo:
#     * Cinta de entrada: 111110111010 (números 5, 3 y 1)
#     * Cinta resultado: 111 (cálculo [(5 + 3 + 1) / 3] = 3)

# %% [markdown]
# Calcular a^nba^m -> a^(n+m)b

# %% [markdown]
# Decidir si m < n,  a^nb^m / n, m > 0, escribiendo en la cinta T (true) o F (false)

# %% [markdown]
# Que recibe un número binario (cadena no vacía de 0’s y 1’s) y devuelve el siguiente número binario (es decir, le suma 1)

# %% [markdown]
# Para eliminar el blanco que separa los dos argumentos x e y, moviendo los símbolos de y un lugar hacia la izquierda. Σ = {a, b}

# %% [markdown]
# MT de 3 cintas que reste el número binario de la segunda cinta del número binario de la primera y deje el resultado en la tercer cinta. Hacer otra, suponiendo que la MT es de 2 cintas y que el resultado se deja sobre la segunda. Hacerlo también para que el resultado quede en la primera

# %% [markdown]
# MT de 3 cintas que determine si el número binario que está en la primera cinta es menor que el de la segunda. Si es menor, escribir el símbolo S sobre la tercer cinta y si no lo es, escribir los símbolos GE sobre la tercer cinta

# %% [markdown]
# Una cinta contiene dos cadenas binarias X e Y separadas por el símbolo * tales que la longitud de cada cadena es la mínima necesaria para representar el número correspondiente (es decir, que ninguno de los números comienzan con cero). En esas condiciones construir una MT que devuelva los valores 0, 1 ó 2 según sea X = Y, X > Y o X < Y respectivamente

# %% [markdown]
# Dados dos números binarios separados por el símbolo *, defina y construya una MT que calcule la suma de ambos números

# %% [markdown]
# Dadas dos cadenas de palotes, separadas por el símbolo \* defina y construya una MT que decida si la primera cadena es submúltiplo de la segunda, y cuántas veces. Pruebe la solución hallada con las siguientes cadenas:
# * |||\*|||||| (es submúltiplo, dos veces)
# * ||\*||||| (no es submúltiplo)

# %% [markdown]
# f(x, y)
# * 0    si x <= y
# * x-y  si x > y
# * x e y codificados en unario
# * x e y se encuentran en C1 separados por un símbolo cero
# * resultado de f(x, y) se dejará en C4
# * C2 se colocará c y en C3 y
#
# * Ejemplo x = 5  y = 3
# * C1: ...□111110111□...
# * C2: ...□11111□□□□□...
# * C3: ...□111□□□□□□□...
# * C4: ...□11□□□□□□□□...

# %% [markdown]
# ![MT x-y](img/MT-multi-xmenosy.png)
